# %%
# input & output

nama = input("Masukkan Nama : ")
alamat = input ("Masukkan Alamat : ")

print("Halo", nama, "Alamat kamu di" , alamat)
print(f"Halo {nama} Alamat kamu di {alamat}")
print("Halo {} alamat kamu di {}".format(nama, alamat))
print("Halo {0} alamat kamu di {1}". format(nama, alamat))
# Out:
# Masukkan Nama : Elihardo
# Masukkan Alamat : sipoldas
# Halo Elihardo Alamat kamu di sipoldas
# Halo Elihardo Alamat kamu di sipoldas
# Halo Elihardo alamat kamu di sipoldas
# Halo Elihardo alamat kamu di sipoldas
