# %%
dic = {
    "name": "John",
    "age": 30,
    "city": "New York
}
series_dic = pd.Series(dic)
print(series_dic)
# Out:
#   File "/tmp/ipython-input-879767323.py", line 4
#     "city": "New York
#             ^
# SyntaxError: unterminated string literal (detected at line 4)
