# %%
data_dictionary = {
    "1" :"ayam",
    "2" : "sapi",
    "3" : "mawar",
    "4" : "kambing",
    "5" : "lily"
}

data_dictionary = data_dictionary.copy()
hapus_tumbuhan1 = data_dictionary.pop("3")
hapus_tumbuhan2 = data_dictionary.pop("5")
hapus_tumbuhan = hapus_tumbuhan1 + " " + hapus_tumbuhan2
print(hapus_tumbuhan)
print(data_dictionary)
# Out:
# mawar lily
# {'1': 'ayam', '2': 'sapi', '4': 'kambing'}

# %%
data_dictionary = {
    "1" :"ayam",
    "2" : "sapi",
    "3" : "mawar",
    "4" : "kambing",
    "5" : "lily"
}

new_data = {}
for key in data_dictionary:
    if int(key) % 2 != 0:
        new_data[key] = "hewan"
    else:
        new_data[key] = data_dictionary[key]
print(new_data)
# Out:
# {'1': 'hewan', '2': 'sapi', '3': 'hewan', '4': 'kambing', '5': 'hewan'}
