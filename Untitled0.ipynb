# %%
nama = input("Masukkan nama : ")
umur = input("Masukkan umur : ")
alamat = input ("Masukkan alamat : ")

print("Halo" , nama "Selamat datang di Koding Akademi! Berikut identitas Anda: " )
print("")
# Out:
#   File "/tmp/ipython-input-911437061.py", line 5
#     print("Halo" , nama "Selamat datang di Koding Akademi! Berikut identitas Anda: " )
#                         ^
# SyntaxError: invalid syntax
