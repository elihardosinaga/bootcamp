# %%
nama = input("masukkan nama Anda = ")
umur = input("masukkan umur anda = ")
alamat = input("masukkan alamat anda = ")

print("nama saya adalah", nama)
print("umur saya adalah", umur)
print("alamat saya adalah", alamat)
print("nama saya {} umur {} asal saya berasal dari {}".format(nama, umur, alamat))
# Out:
# masukkan nama Anda = ELI
# masukkan umur anda = 34 TAHUN#
# masukkan alamat anda = MEDAN
# nama saya adalah ELI
# umur saya adalah 34 TAHUN#
# alamat saya adalah MEDAN
# nama saya ELI umur 34 TAHUN# asal saya berasal dari MEDAN

# %%
nama = input("masukkan nama Anda = ")
umur = input("masukkan umur anda = ")
alamat = input("masukkan alamat anda = ")
# Out:
# masukkan nama Anda = indonesia
# masukkan umur anda = 34 tahun
# masukkan alamat anda = sipoldas

# %%
print(nama + " " + umur + " " + alamat)
# Out:
# indonesia  34 tahun  sipoldas

# %%
print("hallo {}sekarang anda telah berumur {}dan anda lahir di {}".format(nama,umur,alamat))
# Out:
# hallo indonesia sekarang anda telah berumur 34 tahun dan anda lahir di sipoldas

# %%
print("Hallo {0} umur anda adalah {1} dan anda tinggal di {2} sebelumnya".format(nama,umur,alamat))
# Out:
# Hallo indonesia  umur anda adalah 34 tahun  dan anda tinggal di sipoldas  sebelumnya

# %%
print(f"halo {nama} umur kamu adala{umur} dan tinngal di{alamat} sebelum ke ")
